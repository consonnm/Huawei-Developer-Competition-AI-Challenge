# %% [markdown]
# 训练数据说明

# %% [markdown]
# 数据存放地址：obs://zzaa/train_data

# %% [markdown]
# 我们使用使用了队伍收集的数据集（共2001条），该数据集采用医疗+道德法律+文史知识名词细分领域问答的方式：

# %% [markdown]
# 以下是部分数据

# %% [markdown]
# {"input": "高血压的常见症状是什么？", "output": "头痛；头晕；胸闷"}
# {"input": "冠心病的主要病因是什么？", "output": "动脉粥样硬化"}
# {"input": "心肌梗塞的症状有哪些？", "output": "胸痛；气短；恶心"}
# {"input": "房颤是一种什么类型的心律失常？", "output": "心房颤动"}
# {"input": "动脉瘤会导致哪些危险症状？", "output": "出血；疼痛；血栓形成"}
# …………
# {"input": "巴西传统烧烤的经典菜有？", "output": "烤肉串、香蕉叶包裹；大量用盐擦拭"}
# {"input": "埃及传统婚礼的食物有？", "output": "庖丁、阿什乐；糖果和坚果拼盘"}
# {"input": "澳大利亚原住民传统食物包括？", "output": "考拉、鳄鱼；采集的水果和坚果"}
# {"input": "俄罗斯传统餐桌上的俄罗斯酒是？", "output": "伏特加、桑塔利奇；配以小吃和开胃菜"}
# {"input": "南非传统烤肉的方式是？", "output": "布拉式烤肉、博尔特烤肉；香辣酱料搭配"}
# {"input": "韩国传统茶道的器具包括？", "output": "茶杯、茶壶；宜家具有韵味"}
# ....
# {"input": "国际抚养权纠纷中通常考虑哪些因素？", "output": "孩子的最佳利益；孩子的居住地法律"}
# {"input": "国际私法中的司法协助包括哪些内容？", "output": "证据收集；文书送达"}
# {"input": "在国际私法中，国际继承的处理通常遵循什么原则？", "output": "遗产所在地法律；死者国籍法律"}
# {"input": "国际财产法律纠纷中，适用哪些法律？", "output": "财产所在地法律；当事人国籍法律"}
# {"input": "国际私法中关于国际商事仲裁的基本原则是什么？", "output": "仲裁地法律适用；国际商事仲裁协议的尊重"}
# {"input": "国际亲子关系确定通常依据什么原则？", "output": "血缘关系；法律关系"}
# {"input": "国际私法对于国际知识产权纠纷的处理原则是什么？", "output": "保护原则；国际条约适用"}
# {"input": "在国际私法中，如何处理国际劳动合同纠纷？", "output": "劳动地法律适用；国际标准遵循"}
# {"input": "国际私法对于国际婚姻产生的财产分割如何处理？", "output": "婚姻登记地法律；双方协议"}
# {"input": "国际私法中处理跨国亲子抚养费问题的原则是什么？", "output": "孩子居住地法律适用"}
# {"input": "在国际私法中，国际遗嘱的有效性判定依据什么？", "output": "制定地法律；死者国籍法律"}

# %% [markdown]
# 训练代码说明

# %% [markdown]
# 我们并未修改大赛提供的模型微调及模型验证代码，仅引入了其他数据集,以及修改里推理代码的决策逻辑，以及修改了提示工程

# %% [markdown]
# 尝试外挂知识库但是因为知识库数据量限制反而效果不佳

# %% [markdown]
# 模型文件说明

# %% [markdown]
# 模型地址：obs://zzaa/model_4
